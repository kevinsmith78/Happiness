# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
state_region = pd.read_csv("state_geocodes.csv")
state_laborforce = pd.read_csv("LF_participants.csv")
state_laborforce_ba = pd.read_csv("BA_Hold_25_44.csv")
# Post_Secondary_25-44 = "Rankings_mod.csv")
individuals_25_44 = pd.read_csv("Total_25_44.csv")
major_type = pd.read_csv("By_Major_type_mod.csv")
national_ranking = pd.read_csv("National Universities Rankings.csv") 
uni_lat_long = pd.read_csv("Uni_lat_long.csv")

# %%
engine = create_engine('postgresql://postgres:postgres@localhost:5432/Project2')
connection = engine.connect()

# %%
state_region_df = state_region.to_sql("state_region", connection)
state_laborforce_df = state_laborforce.to_sql("state_laborforce", connection)
state_laborforce_ba_df = state_laborforce_ba.to_sql("state_laborforce_ba", connection)
individuals_25_44_df = individuals_25_44.to_sql("individuals_25_44", connection)
major_type_df = major_type.to_sql("major_type", connection)
national_ranking_df = national_ranking.to_sql("national_ranking", connection)
uni_lat_long_df = uni_lat_long.to_sql("uni_lat_long", connection)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-26a123d5e037> in <module>
# ----> 1 state_region_df = state_region.to_sql("state_region", connection)
#       2 state_laborforce_df = state_laborforce.to_sql("state_laborforce", connection)
#       3 state_laborforce_ba_df = state_laborforce_ba.to_sql("state_laborforce_ba", connection)
#       4 individuals_25_44_df = individuals_25_44.to_sql("individuals_25_44", connection)
#       5 major_type_df = major_type.to_sql("major_type", connection)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2603         from pandas.io import sql
#    2604
# -> 2605         sql.to_sql(
#    2606             self,
#    2607             name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     587         )
#     588
# --> 589     pandas_sql.to_sql(
#     590         frame,
#     591         name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1391             dtype=dtype,
#    1392         )
# -> 1393         table.create()
#    1394
#    1395         from sqlalchemy import exc
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in create(self)
#     721         if self.exists():
#     722             if self.if_exists == "fail":
# --> 723                 raise ValueError(f"Table '{self.name}' already exists.")
#     724             elif self.if_exists == "replace":
#     725                 self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'state_region' already exists.

# %%
national_ranking_ql = 'SELECT "national_ranking"."Name", "uni_lat_long"."LAT", "uni_lat_long"."LON", "national_ranking"."Rank", "national_ranking"."Undergrad Enrollment" FROM "national_ranking" LEFT JOIN "uni_lat_long" on "uni_lat_long"."NAME" = "national_ranking"."Name"'

# %%
nat_rank_geo = pd.read_sql(national_ranking_ql, connection)

# %%
nat_rank_geo
# Out:
#                                                   Name        LAT         LON  \
# 0                                    Auburn University  32.599378  -85.488258
# 1                                University of Arizona  32.232672 -110.950815
# 2                               University of Arkansas  36.070009  -94.176981
# 3                             Azusa Pacific University  34.130047 -117.888375
# 4                                     Biola University  33.906203 -118.014374
# ..                                                 ...        ...         ...
# 226                   University of California--Irvine        NaN         NaN
# 227                    University of California--Davis        NaN         NaN
# 228  Indiana University-Purdue University--Indianap...        NaN         NaN
# 229                                  Tulane University        NaN         NaN
# 230                     University of Colorado--Denver        NaN         NaN
#
#      Rank Undergrad Enrollment
# 0      99               21,786
# 1     124               33,732
# 2     135               22,159
# 3     183                5,883
# 4     164                4,225
# ..    ...                  ...
# 226    39               25,256
# 227    44               28,384
# 228   197               21,985
# 229    39                6,662
# 230   197               14,036
#
# [231 rows x 5 columns]

# %%
major_type = pd.read_sql('SELECT * FROM "major_type"', connection)

# %%
major_type
# Out:
#     index                       Major  Unemployment Rate  Underemployment Rate
# 0       0                 Agriculture                3.0                  60.3
# 1       1   Animal and Plant Sciences                2.6                  58.6
# 2       2       Environmental Studies                3.9                  53.7
# 3       3                Architecture                2.2                  27.9
# 4       4              Ethnic Studies                5.1                  51.9
# ..    ...                         ...                ...                   ...
# 69     69       International Affairs                4.1                  53.1
# 70     70                     History                5.5                  53.6
# 71     71    Engineering Technologies                3.1                  45.7
# 72     72  Miscellaneous Technologies                3.2                  52.2
# 73     73                     Overall                3.6                  42.5
#
# [74 rows x 4 columns]

# %%
longitudinal_ql = 'SELECT "state_region"."Name", "individuals_25_44"."2009" AS "2009ind", "state_laborforce"."2009" AS "2009lab", "state_laborforce_ba"."2009" AS "2009ba", "individuals_25_44"."2010" AS "2010ind", "state_laborforce"."2010" AS "2010lab", "state_laborforce_ba"."2010" AS "2010ba", "individuals_25_44"."2011" AS "2011ind", "state_laborforce"."2011" AS "2011lab", "state_laborforce_ba"."2011" AS "2011ba", "individuals_25_44"."2012" AS "2012ind", "state_laborforce"."2012" AS "2012lab", "state_laborforce_ba"."2012" AS "2012ba", "individuals_25_44"."2013" AS "2013ind", "state_laborforce"."2013" AS "2013lab", "state_laborforce_ba"."2013" AS "2013ba", "individuals_25_44"."2014" AS "2014ind", "state_laborforce"."2014" AS "2014ind", "state_laborforce_ba"."2014" AS "2014ba", "individuals_25_44"."2015" AS "2015ind", "state_laborforce"."2015" AS "2015lab", "state_laborforce_ba"."2015" AS "2015ba", "individuals_25_44"."2016" AS "2016ind", "state_laborforce"."2016" AS "2016lab", "state_laborforce_ba"."2016" AS "2016ba", "individuals_25_44"."2017" AS "2017ind", "state_laborforce"."2017" AS "2017lab", "state_laborforce_ba"."2017" AS "2017ba", "individuals_25_44"."2018" AS "2018ind", "state_laborforce"."2018" AS "2018lab", "state_laborforce_ba"."2018" AS "2018ba", "individuals_25_44"."2019" AS "2019ind", "state_laborforce"."2019" AS "2019lab", "state_laborforce_ba"."2019" AS "2019ba" FROM "state_region" LEFT JOIN "individuals_25_44" on "individuals_25_44"."Unnamed: 0" = "state_region"."Name" LEFT JOIN "state_laborforce" on "state_laborforce"."State" = "state_region"."Name" LEFT JOIN "state_laborforce_ba" on "state_laborforce_ba"."State" = "state_region"."Name"'

# %%
longitudinal_df = pd.read_sql(longitudinal_ql, connection)

# %%
longitudinal_df
# Out:
#                     Name     2009ind    2009lab     2009ba     2010ind  \
# 0                Alabama   1,232,200    536,210    303,640   1,228,719
# 1                 Alaska     191,023     92,035     45,860     197,484
# 2                Arizona   1,685,082    807,020    458,075   1,681,042
# 3               Arkansas     743,283    282,850    161,440     743,027
# 4             California  10,493,897  5,662,070  3,270,705  10,508,797
# 5               Colorado   1,415,641    967,040    537,205   1,430,726
# 6            Connecticut     911,836    701,695    354,995     902,627
# 7               Delaware     228,638    136,335     73,655     227,384
# 5     984,155    540,440   1,452,344  1,001,865    559,125  ...    653,905
# 6     707,685    358,585     894,883    716,900    357,970  ...    376,430
# 7     133,790     69,830     227,311    139,350     73,415  ...     78,485
# 8     191,925    127,235     219,040    203,595    138,825  ...    169,630
# 9   2,435,020  1,253,795   4,752,143  2,465,640  1,291,830  ...  1,542,505
# 10  1,369,865    808,440   2,730,710  1,410,055    829,700  ...    914,050
# 11    206,765    109,170     366,528    204,635    106,725  ...    127,000
# 12    185,570    102,010     403,286    190,410    106,170  ...    125,615
# 13  2,198,755  1,256,125   3,491,412  2,218,955  1,280,115  ...  1,373,560
# 14    802,820    438,225   1,664,408    810,825    448,595  ...    503,575
# 15    429,875    229,770     749,668    442,240    238,650  ...    266,910
# 16    452,540    247,320     726,063    459,270    243,650  ...    261,800
# 17    484,165    277,255   1,138,563    501,880    279,375  ...    310,640
# 18    511,150    282,390   1,206,298    495,585    283,640  ...    324,860
# 19    199,100     89,450     311,968    211,635     96,290  ...    105,165
# 20  1,180,845    601,335   1,565,350  1,198,555    627,065  ...    688,420
# 21  1,476,635    803,235   1,739,254  1,494,185    795,925  ...    895,005
# 22  1,315,295    703,205   2,409,274  1,331,395    711,955  ...    781,050
# 23    953,860    529,150   1,399,164    967,780    535,145  ...    576,235
# 24    286,915    159,265     761,330    297,430    162,730  ...    177,815
# 25    839,515    461,865   1,524,815    846,725    466,570  ...    515,485
# 26    148,435     74,345     237,427    149,775     76,275  ...     82,740
# 27    291,595    157,755     469,569    284,365    153,065  ...    182,720
# 28    296,165    163,595     765,448    304,500    161,565  ...    187,330
# 29    247,905    116,700     318,995    248,215    118,255  ...    128,275
# 30  1,740,035    951,630   2,328,999  1,748,330    945,455  ...  1,023,980
# 31    247,230    114,135     521,267    255,705    119,740  ...    130,290
# 32  3,554,290  2,023,840   5,280,203  3,594,955  2,066,560  ...  2,283,450
# 33  1,316,960    753,805   2,576,613  1,351,590    776,395  ...    893,505
# 34    107,880     58,935     170,338    102,470     55,890  ...     73,320
# 35  1,560,610    845,475   2,870,474  1,556,995    840,370  ...    942,570
# 36    438,440    233,470     977,707    464,375    249,805  ...    273,315
# 37    567,305    315,040   1,034,410    574,620    317,300  ...    392,680
# 38  1,948,405  1,040,685   3,125,681  1,940,200  1,045,715  ...  1,209,520
# 39    175,495     92,970     262,028    186,075     91,170  ...    104,775
# 40    584,995    312,195   1,191,652    560,870    315,050  ...    370,085
# 41    116,745     60,425     201,106    115,185     59,990  ...     69,025
# 42    784,780    442,130   1,677,851    811,460    455,455  ...    516,755
# 43  3,316,610  1,891,850   7,198,429  3,416,050  1,972,065  ...  2,389,780
# 44    362,080    232,955     791,821    373,740    238,955  ...    297,280
# 45    115,830     51,125     146,433    126,330     56,930  ...     57,420
# 38   3,168,645  2,264,910  1,227,340   3,196,393  2,297,270  1,259,265
# 39     267,252    198,040    102,340     270,705    200,310    100,995
# 40   1,268,559    708,015    378,490   1,285,375    731,530    395,245
# 41     216,529    131,095     66,485     218,772    137,995     76,385
# 42   1,750,044    978,550    556,840   1,773,550    995,435    553,200
# 43   7,989,180  4,218,150  2,486,160   8,098,850  4,433,840  2,606,715
# 44     880,412    484,790    318,820     898,476    499,305    325,885
# 45     142,874    129,590     58,870     144,499    137,270     64,645
# 46   2,274,775  1,763,990    970,010   2,288,181  1,797,625    992,345
# 47   2,099,899  1,369,915    799,730   2,153,138  1,440,765    864,890
# 48     435,799    188,750    102,440     431,393    201,375    106,375
# 49   1,425,720    961,490    512,570   1,440,982    962,100    511,990
# 50     150,863     78,275     43,110     150,456     78,605     44,110
#
#        2019ind    2019lab     2019ba
# 0    1,240,535    651,555    354,540
# 1      213,353    106,425     63,145
# 2    1,903,120  1,054,415    571,695
# 3      767,131    357,580    202,205
# 4   11,335,052  7,324,340  4,330,535
# 5    1,711,425  1,339,255    771,390
# 6      875,170    793,145    390,425
# 7      242,181    169,885     85,110
# 8      273,510    268,705    192,555
# 9    5,399,953  3,296,270  1,745,405
# 10   2,874,215  1,817,970  1,005,425
# 11     381,798    237,495    135,965
# 12     463,662    239,640    139,400
# 13   3,395,231  2,539,540  1,441,205
# 14   1,719,646    986,035    536,670
# 15     783,365    504,310    282,075
# 16     743,951    513,680    277,340
# 17   1,138,333    606,195    336,365
# 18   1,248,081    594,550    350,875
# 19     316,883    247,165    115,885
# 20   1,611,462  1,390,770    712,675
# 21   1,842,827  1,820,510    974,100
# 22   2,477,786  1,601,410    851,380
# 23   1,488,193  1,179,275    647,145
# 24     759,501    323,610    172,285
# 25   1,579,626  1,006,795    561,540
# 26     268,181    182,260    102,260
# 27     498,477    356,010    202,530
# 28     863,621    388,490    219,215
# 29     329,316    287,570    139,730
# 30   2,289,971  2,080,220  1,101,485
# 31     538,933    270,275    137,595
# 32   5,297,612  4,241,845  2,418,300
# 33   2,719,496  1,763,970    978,850
# 34     207,147    127,920     75,905
# 35   2,952,186  1,866,975  1,015,845
# 36   1,041,466    521,520    284,680
# 37   1,172,996    762,175    439,290
# 38   3,222,875  2,340,735  1,273,570
# 39     273,548    210,470    110,670
# 40   1,303,358    763,775    416,770
# 41     220,928    142,325     74,695
# 42   1,797,314  1,059,525    592,510
# 43   8,219,202  4,583,845  2,717,435
# 44     915,259    519,950    334,445
# 45     145,675    135,120     63,810
# 46   2,302,877  1,820,625  1,001,990
# 47   2,200,216  1,489,970    878,310
# 48     427,806    201,405    111,125
# 49   1,454,297  1,006,925    542,485
# 50     150,718     80,370     44,925
#
# [51 rows x 34 columns]

# %%
longitudinal_df.to_csv('longitudinal.csv')
